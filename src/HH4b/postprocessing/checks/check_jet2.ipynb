# %% [markdown]
# # Goal
# The fraction of events in the signal region bin 1, bin2 and bin3 that have Jet 2 TXbb < 0.3
#
# ```python
# mask_bin1 = (bdt_events["H2TXbb"] > args.txbb_wps[0]) & (
#     bdt_events[bdt_score] > args.bdt_wps[0]
# )
#
# mask_bin2 = (
#     (bdt_events["H2TXbb"] > args.txbb_wps[1])
#     & (bdt_events[bdt_score] > args.bdt_wps[1])
#     & ~(mask_bin1)
#     & ~(mask_corner)
#     & ~(mask_vbf)
# )
#
#
# mask_bin3 = (
#     (bdt_events["H2TXbb"] > args.txbb_wps[1])
#     & (bdt_events[bdt_score] > args.bdt_wps[2])
#     & ~(mask_bin1)
#     & ~(mask_bin2)
#     & ~(mask_vbf)
# )
# ```
# In this case
# ```python
# args.txbb_wps = [0.9375, 0.7475]
# args.bdt_wps = [0.9075, 0.6375, 0.03]
# ```

# %%
from pathlib import Path
import pandas as pd

# %% [markdown]
# An explict way:
# ```python
# # variables used in `process.sh`
# txbb_wps = [0.9375, 0.7475]
# bdt_wps = [0.9075, 0.6375, 0.03]
# vbf = True  # --vbf
# vbf_priority = False  # --no-vbf-priority
# vbf_txbb_wp = 0.775
# vbf_bdt_wp = 0.9825
#
# # bins, as defined in PostProcess.py
# # bin 1
# mask_bin1 = (df["H2TXbb"] > txbb_wps[0]) & (
#     df["bdt_score"] > bdt_wps[0]
# )
#
# # bin 2
# if vbf:
#     mask_vbf = (df["bdt_score_vbf"] > vbf_bdt_wp) & (
#         df["H2TXbb"] > vbf_txbb_wp
#     )
# else:
#     mask_vbf = np.zeros(len(df), dtype=bool)
#
# if vbf_priority:
#     # prioritize VBF region i.e. veto events in bin1 that pass the VBF selection
#     mask_bin1 = mask_bin1 & ~(mask_vbf)
# else:
#     # prioritize bin 1 i.e. veto events in VBF region that pass the bin 1 selection
#     mask_vbf = mask_vbf & ~(mask_bin1)
# mask_corner = (df["H2TXbb"] < txbb_wps[0]) & (
#     df["bdt_score"] < bdt_wps[0]
# )
# mask_bin2 = (
#     (df["H2TXbb"] > txbb_wps[1])
#     & (df["bdt_score"] > bdt_wps[1])
#     & ~(mask_bin1)
#     & ~(mask_corner)
#     & ~(mask_vbf)
# )
#
# # bin 3
# mask_bin3 = (
#     (df["H2TXbb"] > txbb_wps[1])
#     & (df["bdt_score"] > bdt_wps[2])
#     & ~(mask_bin1)
#     & ~(mask_bin2)
#     & ~(mask_vbf)
# )
# ```
# However, we already stored category in the dataframe

# %%
eras = ["2022", "2022EE", "2023BPix", "2023"]
TXbb_th = 0.3

txbb_wps = [0.9375, 0.7475]
bdt_wps = [0.9075, 0.6375, 0.03]
vbf = True  # --vbf
vbf_priority = False  # --no-vbf-priority
vbf_txbb_wp = 0.775
vbf_bdt_wp = 0.9825

era_stats = {}
era_stats["TXbb_th"]= TXbb_th
args = {}
args["txbb_wps"] = txbb_wps
args["bdt_wps"] = bdt_wps
args["vbf"] = vbf
args["vbf_priority"] = vbf_priority
args["vbf_txbb_wp"] = vbf_txbb_wp
args["vbf_bdt_wp"] = vbf_bdt_wp
era_stats["args"] = args


for era in eras:
    counts = {}
    path = Path(f"events/processed_events_{era}.pkl")
    if path.exists():
        df_dict = pd.read_pickle(path)
    else:
        print(f"File {path} not found")
        continue
    
    signal_stats = {}
    for signal_type in df_dict.keys():
        df = df_dict[signal_type]
        dfs_bin = [df[df["Category"] == i + 1] for i in range(3)]

        stats = {}
        total_events = len(df)
        stats["events"] = total_events
        print(f"Total events for {signal_type} in {era}: {total_events}")
        stats["events_by_bin"] = {}
        stats["events_pass_by_bin"] = {}
        stats["fraction_pass_by_bin"] = {}

        for i, df_bin in enumerate(dfs_bin):
            count = len(df_bin)
            stats["events_by_bin"][i+1] = int(count)
            pass_count = (df_bin["ak8FatJet2TXbb"] < TXbb_th).sum()
            stats["events_pass_by_bin"][i+1] = int(pass_count)
            if count != 0:
                fraction = pass_count / count
            else:
                fraction = -1
            stats["fraction_pass_by_bin"][i+1] = float(fraction)
            print(f"Events in bin {i+1}: {pass_count} / {count} ({fraction*100:.2f}%)")
        
        signal_stats[signal_type] = stats
        
    era_stats[era] = signal_stats
# Out:
# Total events for data in 2022: 69041
# Events in bin 1: 0 / 7 (0.00%)
# Events in bin 2: 1 / 55 (1.82%)
# Events in bin 3: 14 / 586 (2.39%)
# Total events for ttbar in 2022: 144348
# Events in bin 1: 0 / 10 (0.00%)
# Events in bin 2: 3 / 329 (0.91%)
# Events in bin 3: 95 / 4617 (2.06%)
# Total events for gghtobb in 2022: 72599
# Events in bin 1: 2 / 54 (3.70%)
# Events in bin 2: 2 / 229 (0.87%)
# Events in bin 3: 5 / 369 (1.36%)
# Total events for vbfhtobb in 2022: 455
# Events in bin 1: 0 / 0 (-100.00%)
# Events in bin 2: 0 / 0 (-100.00%)
# Events in bin 3: 0 / 0 (-100.00%)
# Total events for vhtobb in 2022: 49046
# Events in bin 1: 16 / 921 (1.74%)
# Events in bin 2: 18 / 1540 (1.17%)
# Events in bin 3: 37 / 4138 (0.89%)
# Total events for novhhtobb in 2022: 73054
# Events in bin 1: 2 / 54 (3.70%)
# Events in bin 2: 2 / 229 (0.87%)
# Events in bin 3: 5 / 369 (1.36%)
# Total events for tthtobb in 2022: 10754
# Events in bin 1: 1 / 18 (5.56%)
# Events in bin 2: 18 / 219 (8.22%)
# Events in bin 3: 22 / 463 (4.75%)
# Total events for diboson in 2022: 1378
# Events in bin 1: 0 / 0 (-100.00%)
# Events in bin 2: 0 / 1 (0.00%)
# Events in bin 3: 0 / 31 (0.00%)
# Total events for vjets in 2022: 54126
# Events in bin 1: 0 / 5 (0.00%)
# Events in bin 2: 1 / 21 (4.76%)
# Events in bin 3: 25 / 344 (7.27%)
# Total events for hh4b in 2022: 31288
# Events in bin 1: 50 / 3791 (1.32%)
# Events in bin 2: 82 / 6687 (1.23%)
# Events in bin 3: 51 / 4570 (1.12%)
# Total events for hh4b-kl0 in 2022: 17351
# Events in bin 1: 26 / 2079 (1.25%)
# Events in bin 2: 47 / 3673 (1.28%)
# Events in bin 3: 31 / 2562 (1.21%)
# Total events for hh4b-kl2p45 in 2022: 9020
# Events in bin 1: 11 / 1133 (0.97%)
# Events in bin 2: 29 / 1964 (1.48%)
# Events in bin 3: 10 / 1366 (0.73%)
# Total events for hh4b-kl5 in 2022: 6238
# Events in bin 1: 9 / 631 (1.43%)
# Events in bin 2: 16 / 1012 (1.58%)
# Events in bin 3: 15 / 761 (1.97%)
# Total events for vbfhh4b in 2022: 4077
# Events in bin 1: 24 / 491 (4.89%)
# Events in bin 2: 26 / 366 (7.10%)
# Events in bin 3: 25 / 545 (4.59%)
# Total events for vbfhh4b-k2v0 in 2022: 135034
# Events in bin 1: 190 / 31567 (0.60%)
# Events in bin 2: 105 / 9121 (1.15%)
# Events in bin 3: 138 / 14487 (0.95%)
# Total events for vbfhh4b-kv1p74-k2v1p37-kl14p4 in 2022: 2850
# Events in bin 1: 1 / 661 (0.15%)
# Events in bin 2: 0 / 101 (0.00%)
# Events in bin 3: 3 / 289 (1.04%)
# Total events for vbfhh4b-kvm0p012-k2v0p03-kl10p2 in 2022: 45602
# Events in bin 1: 73 / 11082 (0.66%)
# Events in bin 2: 29 / 2609 (1.11%)
# Events in bin 3: 41 / 4760 (0.86%)
# Total events for vbfhh4b-kvm0p758-k2v1p44-klm19p3 in 2022: 4057
# Events in bin 1: 8 / 862 (0.93%)
# Events in bin 2: 6 / 343 (1.75%)
# Events in bin 3: 5 / 463 (1.08%)
# Total events for vbfhh4b-kvm0p962-k2v0p959-klm1p43 in 2022: 1339
# Events in bin 1: 10 / 206 (4.85%)
# Events in bin 2: 5 / 103 (4.85%)
# Events in bin 3: 8 / 116 (6.90%)
# Total events for vbfhh4b-kvm1p21-k2v1p94-klm0p94 in 2022: 41597
# Events in bin 1: 71 / 10119 (0.70%)
# Events in bin 2: 36 / 2623 (1.37%)
# Events in bin 3: 54 / 4183 (1.29%)
# Total events for vbfhh4b-kvm1p6-k2v2p72-klm1p36 in 2022: 1185
# Events in bin 1: 9 / 255 (3.53%)
# Events in bin 2: 4 / 72 (5.56%)
# Events in bin 3: 9 / 101 (8.91%)
# Total events for vbfhh4b-kvm1p83-k2v3p57-klm3p39 in 2022: 3450
# Events in bin 1: 12 / 764 (1.57%)
# Events in bin 2: 18 / 266 (6.77%)
# Events in bin 3: 9 / 274 (3.28%)
# Total events for vbfhh4b-kvm2p12-k2v3p87-klm5p96 in 2022: 2296
# Events in bin 1: 2 / 438 (0.46%)
# Events in bin 2: 6 / 241 (2.49%)
# Events in bin 3: 5 / 258 (1.94%)
# Total events for data in 2022EE: 209539
# Events in bin 1: 1 / 12 (8.33%)
# Events in bin 2: 4 / 172 (2.33%)
# Events in bin 3: 41 / 1748 (2.35%)
# Total events for ttbar in 2022EE: 463798
# Events in bin 1: 1 / 65 (1.54%)
# Events in bin 2: 17 / 976 (1.74%)
# Events in bin 3: 283 / 15072 (1.88%)
# Total events for gghtobb in 2022EE: 253062
# Events in bin 1: 4 / 181 (2.21%)
# Events in bin 2: 24 / 923 (2.60%)
# Events in bin 3: 22 / 1339 (1.64%)
# Total events for vbfhtobb in 2022EE: 1482
# Events in bin 1: 0 / 1 (0.00%)
# Events in bin 2: 0 / 0 (-100.00%)
# Events in bin 3: 0 / 3 (0.00%)
# Total events for vhtobb in 2022EE: 172183
# Events in bin 1: 30 / 3083 (0.97%)
# Events in bin 2: 62 / 5292 (1.17%)
# Events in bin 3: 121 / 14408 (0.84%)
# Total events for novhhtobb in 2022EE: 254544
# Events in bin 1: 4 / 182 (2.20%)
# Events in bin 2: 24 / 923 (2.60%)
# Events in bin 3: 22 / 1342 (1.64%)
# Total events for tthtobb in 2022EE: 36983
# Events in bin 1: 6 / 75 (8.00%)
# Events in bin 2: 41 / 716 (5.73%)
# Events in bin 3: 73 / 1551 (4.71%)
# Total events for diboson in 2022EE: 4572
# Events in bin 1: 0 / 2 (0.00%)
# Events in bin 2: 0 / 4 (0.00%)
# Events in bin 3: 0 / 74 (0.00%)
# Total events for vjets in 2022EE: 179054
# Events in bin 1: 0 / 18 (0.00%)
# Events in bin 2: 4 / 82 (4.88%)
# Events in bin 3: 49 / 1120 (4.38%)
# Total events for hh4b in 2022EE: 95972
# Events in bin 1: 130 / 11952 (1.09%)
# Events in bin 2: 240 / 20360 (1.18%)
# Events in bin 3: 137 / 14310 (0.96%)
# Total events for hh4b-kl0 in 2022EE: 61713
# Events in bin 1: 86 / 7174 (1.20%)
# Events in bin 2: 147 / 12884 (1.14%)
# Events in bin 3: 76 / 8990 (0.85%)
# Total events for hh4b-kl2p45 in 2022EE: 30778
# Events in bin 1: 51 / 3918 (1.30%)
# Events in bin 2: 76 / 6354 (1.20%)
# Events in bin 3: 40 / 4701 (0.85%)
# Total events for hh4b-kl5 in 2022EE: 23468
# Events in bin 1: 42 / 2358 (1.78%)
# Events in bin 2: 57 / 3718 (1.53%)
# Events in bin 3: 34 / 2886 (1.18%)
# Total events for vbfhh4b in 2022EE: 13596
# Events in bin 1: 67 / 1711 (3.92%)
# Events in bin 2: 68 / 1208 (5.63%)
# Events in bin 3: 82 / 1708 (4.80%)
# Total events for vbfhh4b-k2v0 in 2022EE: 448999
# Events in bin 1: 661 / 103900 (0.64%)
# Events in bin 2: 353 / 30375 (1.16%)
# Events in bin 3: 461 / 48146 (0.96%)
# Total events for vbfhh4b-kv1p74-k2v1p37-kl14p4 in 2022EE: 9866
# Events in bin 1: 9 / 2356 (0.38%)
# Events in bin 2: 3 / 393 (0.76%)
# Events in bin 3: 6 / 913 (0.66%)
# Total events for vbfhh4b-kvm0p012-k2v0p03-kl10p2 in 2022EE: 160889
# Events in bin 1: 185 / 39216 (0.47%)
# Events in bin 2: 113 / 9561 (1.18%)
# Events in bin 3: 168 / 16253 (1.03%)
# Total events for vbfhh4b-kvm0p758-k2v1p44-klm19p3 in 2022EE: 14595
# Events in bin 1: 15 / 3003 (0.50%)
# Events in bin 2: 14 / 1308 (1.07%)
# Events in bin 3: 12 / 1627 (0.74%)
# Total events for vbfhh4b-kvm0p962-k2v0p959-klm1p43 in 2022EE: 4594
# Events in bin 1: 23 / 782 (2.94%)
# Events in bin 2: 26 / 331 (7.85%)
# Events in bin 3: 19 / 343 (5.54%)
# Total events for vbfhh4b-kvm1p21-k2v1p94-klm0p94 in 2022EE: 146306
# Events in bin 1: 242 / 35762 (0.68%)
# Events in bin 2: 138 / 9256 (1.49%)
# Events in bin 3: 160 / 14340 (1.12%)
# Total events for vbfhh4b-kvm1p6-k2v2p72-klm1p36 in 2022EE: 3957
# Events in bin 1: 20 / 794 (2.52%)
# Events in bin 2: 20 / 251 (7.97%)
# Events in bin 3: 20 / 332 (6.02%)
# Total events for vbfhh4b-kvm1p83-k2v3p57-klm3p39 in 2022EE: 12042
# Events in bin 1: 48 / 2459 (1.95%)
# Events in bin 2: 36 / 950 (3.79%)
# Events in bin 3: 32 / 1042 (3.07%)
# Total events for vbfhh4b-kvm2p12-k2v3p87-klm5p96 in 2022EE: 8141
# Events in bin 1: 11 / 1526 (0.72%)
# Events in bin 2: 13 / 774 (1.68%)
# Events in bin 3: 11 / 982 (1.12%)
# Total events for data in 2023BPix: 63889
# Events in bin 1: 0 / 1 (0.00%)
# Events in bin 2: 1 / 53 (1.89%)
# Events in bin 3: 13 / 533 (2.44%)
# Total events for ttbar in 2023BPix: 59393
# Events in bin 1: 1 / 9 (11.11%)
# Events in bin 2: 8 / 137 (5.84%)
# Events in bin 3: 39 / 2006 (1.94%)
# Total events for gghtobb in 2023BPix: 58187
# Events in bin 1: 2 / 49 (4.08%)
# Events in bin 2: 4 / 183 (2.19%)
# Events in bin 3: 5 / 347 (1.44%)
# Total events for vbfhtobb in 2023BPix: 2222
# Events in bin 1: 0 / 1 (0.00%)
# Events in bin 2: 0 / 1 (0.00%)
# Events in bin 3: 0 / 9 (0.00%)
# Total events for vhtobb in 2023BPix: 77243
# Events in bin 1: 10 / 649 (1.54%)
# Events in bin 2: 14 / 1260 (1.11%)
# Events in bin 3: 36 / 5552 (0.65%)
# Total events for novhhtobb in 2023BPix: 58187
# Events in bin 1: 2 / 49 (4.08%)
# Events in bin 2: 4 / 183 (2.19%)
# Events in bin 3: 5 / 347 (1.44%)
# Total events for tthtobb in 2023BPix: 20400
# Events in bin 1: 3 / 44 (6.82%)
# Events in bin 2: 26 / 409 (6.36%)
# Events in bin 3: 59 / 956 (6.17%)
# Total events for diboson in 2023BPix: 931
# Events in bin 1: 0 / 0 (-100.00%)
# Events in bin 2: 0 / 0 (-100.00%)
# Events in bin 3: 0 / 3 (0.00%)
# Total events for vjets in 2023BPix: 50832
# Events in bin 1: 0 / 5 (0.00%)
# Events in bin 2: 1 / 14 (7.14%)
# Events in bin 3: 15 / 332 (4.52%)
# Total events for hh4b in 2023BPix: 37491
# Events in bin 1: 47 / 3897 (1.21%)
# Events in bin 2: 69 / 6399 (1.08%)
# Events in bin 3: 88 / 9299 (0.95%)
# Total events for hh4b-kl0 in 2023BPix: 22014
# Events in bin 1: 17 / 2157 (0.79%)
# Events in bin 2: 46 / 3838 (1.20%)
# Events in bin 3: 45 / 5346 (0.84%)
# Total events for hh4b-kl2p45 in 2023BPix: 11332
# Events in bin 1: 13 / 1187 (1.10%)
# Events in bin 2: 21 / 1953 (1.08%)
# Events in bin 3: 31 / 2883 (1.08%)
# Total events for hh4b-kl5 in 2023BPix: 8388
# Events in bin 1: 14 / 727 (1.93%)
# Events in bin 2: 13 / 1155 (1.13%)
# Events in bin 3: 22 / 1684 (1.31%)
# Total events for vbfhh4b in 2023BPix: 11397
# Events in bin 1: 49 / 1060 (4.62%)
# Events in bin 2: 38 / 861 (4.41%)
# Events in bin 3: 104 / 2356 (4.41%)
# Total events for vbfhh4b-k2v0 in 2023BPix: 403434
# Events in bin 1: 460 / 70790 (0.65%)
# Events in bin 2: 302 / 25210 (1.20%)
# Events in bin 3: 766 / 74773 (1.02%)
# Total events for vbfhh4b-kv1p74-k2v1p37-kl14p4 in 2023BPix: 38306
# Events in bin 1: 26 / 6646 (0.39%)
# Events in bin 2: 16 / 1400 (1.14%)
# Events in bin 3: 51 / 5987 (0.85%)
# Total events for vbfhh4b-kvm0p012-k2v0p03-kl10p2 in 2023BPix: 625873
# Events in bin 1: 660 / 115024 (0.57%)
# Events in bin 2: 427 / 33872 (1.26%)
# Events in bin 3: 1012 / 108961 (0.93%)
# Total events for vbfhh4b-kvm0p758-k2v1p44-klm19p3 in 2023BPix: 54426
# Events in bin 1: 87 / 8683 (1.00%)
# Events in bin 2: 51 / 4403 (1.16%)
# Events in bin 3: 103 / 10651 (0.97%)
# Total events for vbfhh4b-kvm0p962-k2v0p959-klm1p43 in 2023BPix: 16833
# Events in bin 1: 98 / 2157 (4.54%)
# Events in bin 2: 85 / 1158 (7.34%)
# Events in bin 3: 172 / 2338 (7.36%)
# Total events for vbfhh4b-kvm1p21-k2v1p94-klm0p94 in 2023BPix: 561169
# Events in bin 1: 759 / 103418 (0.73%)
# Events in bin 2: 533 / 32741 (1.63%)
# Events in bin 3: 1129 / 97489 (1.16%)
# Total events for vbfhh4b-kvm1p6-k2v2p72-klm1p36 in 2023BPix: 14407
# Events in bin 1: 67 / 2315 (2.89%)
# Events in bin 2: 61 / 864 (7.06%)
# Events in bin 3: 103 / 2028 (5.08%)
# Total events for vbfhh4b-kvm1p83-k2v3p57-klm3p39 in 2023BPix: 44808
# Events in bin 1: 129 / 6956 (1.85%)
# Events in bin 2: 113 / 3252 (3.47%)
# Events in bin 3: 218 / 7253 (3.01%)
# Total events for vbfhh4b-kvm2p12-k2v3p87-klm5p96 in 2023BPix: 29994
# Events in bin 1: 33 / 4465 (0.74%)
# Events in bin 2: 31 / 2618 (1.18%)
# Events in bin 3: 58 / 6211 (0.93%)
# Total events for data in 2023: 133402
# Events in bin 1: 1 / 4 (25.00%)
# Events in bin 2: 2 / 88 (2.27%)
# Events in bin 3: 41 / 1087 (3.77%)
# Total events for ttbar in 2023: 131592
# Events in bin 1: 0 / 23 (0.00%)
# Events in bin 2: 6 / 289 (2.08%)
# Events in bin 3: 91 / 4493 (2.03%)
# Total events for gghtobb in 2023: 171525
# Events in bin 1: 1 / 120 (0.83%)
# Events in bin 2: 15 / 605 (2.48%)
# Events in bin 3: 21 / 1057 (1.99%)
# Total events for vbfhtobb in 2023: 4690
# Events in bin 1: 0 / 4 (0.00%)
# Events in bin 2: 0 / 2 (0.00%)
# Events in bin 3: 0 / 13 (0.00%)
# Total events for vhtobb in 2023: 138889
# Events in bin 1: 5 / 1102 (0.45%)
# Events in bin 2: 16 / 1997 (0.80%)
# Events in bin 3: 76 / 9125 (0.83%)
# Total events for novhhtobb in 2023: 171525
# Events in bin 1: 1 / 120 (0.83%)
# Events in bin 2: 15 / 605 (2.48%)
# Events in bin 3: 21 / 1057 (1.99%)
# Total events for tthtobb in 2023: 48516
# Events in bin 1: 12 / 124 (9.68%)
# Events in bin 2: 55 / 1001 (5.49%)
# Events in bin 3: 109 / 2275 (4.79%)
# Total events for diboson in 2023: 1531
# Events in bin 1: 0 / 2 (0.00%)
# Events in bin 2: 0 / 2 (0.00%)
# Events in bin 3: 1 / 41 (2.44%)
# Total events for vjets in 2023: 113888
# Events in bin 1: 0 / 5 (0.00%)
# Events in bin 2: 4 / 56 (7.14%)
# Events in bin 3: 43 / 806 (5.33%)
# Total events for hh4b in 2023: 85117
# Events in bin 1: 101 / 8779 (1.15%)
# Events in bin 2: 191 / 14652 (1.30%)
# Events in bin 3: 201 / 21169 (0.95%)
# Total events for hh4b-kl0 in 2023: 7401
# Events in bin 1: 18 / 719 (2.50%)
# Events in bin 2: 13 / 1260 (1.03%)
# Events in bin 3: 15 / 1789 (0.84%)
# Total events for hh4b-kl2p45 in 2023: 25038
# Events in bin 1: 29 / 2640 (1.10%)
# Events in bin 2: 48 / 4235 (1.13%)
# Events in bin 3: 65 / 6370 (1.02%)
# Total events for hh4b-kl5 in 2023: 17967
# Events in bin 1: 17 / 1526 (1.11%)
# Events in bin 2: 45 / 2418 (1.86%)
# Events in bin 3: 37 / 3521 (1.05%)
# Total events for vbfhh4b in 2023: 24442
# Events in bin 1: 105 / 2324 (4.52%)
# Events in bin 2: 107 / 1975 (5.42%)
# Events in bin 3: 228 / 5149 (4.43%)
# Total events for vbfhh4b-k2v0 in 2023: 894333
# Events in bin 1: 1037 / 157908 (0.66%)
# Events in bin 2: 755 / 57050 (1.32%)
# Events in bin 3: 1625 / 165683 (0.98%)
# Total events for vbfhh4b-kv1p74-k2v1p37-kl14p4 in 2023: 84303
# Events in bin 1: 61 / 14343 (0.43%)
# Events in bin 2: 32 / 3179 (1.01%)
# Events in bin 3: 114 / 13349 (0.85%)
# Total events for vbfhh4b-kvm0p012-k2v0p03-kl10p2 in 2023: 1371494
# Events in bin 1: 1472 / 254030 (0.58%)
# Events in bin 2: 983 / 75260 (1.31%)
# Events in bin 3: 2317 / 238554 (0.97%)
# Total events for vbfhh4b-kvm0p758-k2v1p44-klm19p3 in 2023: 120696
# Events in bin 1: 153 / 19170 (0.80%)
# Events in bin 2: 93 / 9829 (0.95%)
# Events in bin 3: 254 / 23609 (1.08%)
# Total events for vbfhh4b-kvm0p962-k2v0p959-klm1p43 in 2023: 38524
# Events in bin 1: 205 / 4936 (4.15%)
# Events in bin 2: 223 / 2694 (8.28%)
# Events in bin 3: 375 / 5373 (6.98%)
# Total events for vbfhh4b-kvm1p21-k2v1p94-klm0p94 in 2023: 1234081
# Events in bin 1: 1706 / 228648 (0.75%)
# Events in bin 2: 1176 / 73979 (1.59%)
# Events in bin 3: 2439 / 213672 (1.14%)
# Total events for vbfhh4b-kvm1p6-k2v2p72-klm1p36 in 2023: 32231
# Events in bin 1: 129 / 5251 (2.46%)
# Events in bin 2: 152 / 1914 (7.94%)
# Events in bin 3: 294 / 4659 (6.31%)
# Total events for vbfhh4b-kvm1p83-k2v3p57-klm3p39 in 2023: 83623
# Events in bin 1: 299 / 13440 (2.22%)
# Events in bin 2: 224 / 5954 (3.76%)
# Events in bin 3: 389 / 13250 (2.94%)
# Total events for vbfhh4b-kvm2p12-k2v3p87-klm5p96 in 2023: 54767
# Events in bin 1: 67 / 8190 (0.82%)
# Events in bin 2: 57 / 4952 (1.15%)
# Events in bin 3: 127 / 11239 (1.13%)

# %%
import json
with open("counts_jet2.json", "w") as f:
    json.dump(era_stats, f)
